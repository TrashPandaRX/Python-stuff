# %%
# note to self. if modules not working, might have to install them into this virtual environment first via "!pip3 install MODULE-NAME-HERE"
import pandas
import os
from bs4 import BeautifulSoup
import requests

# %%
# my usual solution, but __file__ doesnt work in jupyter notebooks: x = os.path.dirname(__file__)
x = os.path.abspath('')
x = x + "/readsample2.csv"
df = pandas.read_csv(x)
df
# Out:
#          4     6     1
# 5        3     2     4
# None  None  None  None

# %%
r = requests.get("https://en.wikipedia.org/wiki/Eagle")
print(r.content)
# Out:
# b'<!DOCTYPE html>\n<html class="client-nojs" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8"/>\n<title>Eagle - Wikipedia</title>\n<script>document.documentElement.className="client-js";RLCONF={"wgBreakFrames":false,"wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgRequestId":"be9f2a9f-0ce8-4f3d-8826-839ad00516a5","wgCSPNonce":false,"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":false,"wgNamespaceNumber":0,"wgPageName":"Eagle","wgTitle":"Eagle","wgCurRevisionId":1088681040,"wgRevisionId":1088681040,"wgArticleId":37602,"wgIsArticle":true,"wgIsRedirect":false,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["CS1 German-language sources (de)","Webarchive template wayback links","Articles with short description","Short description is different from Wikidata","Use dmy dates from
# ...

# %%
soup = BeautifulSoup(r.content)
print(soup.prettify)
# Out:
# <bound method Tag.prettify of <!DOCTYPE html>
#
# <html class="client-nojs" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Eagle - Wikipedia</title>
# ...
